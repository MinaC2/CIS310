# %% [markdown]
# # Minahil Chaudhary
# ## Week 15 - 12/01/2022
# ### Python Data Visualization - Making information visualization using plots

# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import DataFrame, Series

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = randn(10)
data
# Out:
# array([ 0.89654451,  0.06328704, -0.74179509, -0.87844347, -0.2628605 ,
#        -0.83376559,  0.78048619, -1.97406502, -0.12547928, -0.39966823])

# %%
s = Series(data)

# %%
s
# Out:
# 0    0.896545
# 1    0.063287
# 2   -0.741795
# 3   -0.878443
# 4   -0.262861
# 5   -0.833766
# 6    0.780486
# 7   -1.974065
# 8   -0.125479
# 9   -0.399668
# dtype: float64

# %%
plt.plot(data)

# %%
plt.plot(s)

# %%
data = randn(20)
df = DataFrame(data)
df
# Out:
#            0
# 0  -0.382919
# 1  -1.038907
# 2   1.211737
# 3   0.700283
# 4   0.877924
# 5   0.037158
# 6   0.933678
# 7  -0.233638
# 8   0.759405
# 9   0.102817
# 10  1.081097
# 11  0.369451
# 12 -2.978103
# 13 -1.887637
# 14 -0.616385
# 15 -1.059766
# 16 -1.430591
# 17 -1.654129
# 18 -0.593283
# 19  0.958959

# %%
plt.plot(df)

# %%
dataset1 = randn(100)
dataset1
# Out:
# array([ 1.92297258e-02, -9.56923879e-01,  1.57046640e+00, -9.67203983e-01,
#         6.85338395e-01,  2.06070011e-01, -1.25607948e+00,  1.56113700e+00,
#         1.15058967e-01, -4.96043473e-01,  1.51314027e+00, -1.32098484e+00,
#         1.98315024e+00, -1.16665525e+00, -9.46727923e-01,  1.34041482e+00,
#        -1.99410245e+00,  1.33499410e+00,  6.55149760e-02, -5.85799393e-01,
#        -6.49779333e-01,  3.03933804e-02,  7.47185420e-01, -1.72673264e+00,
#         6.70963758e-01, -9.45196221e-01,  1.45453777e+00, -1.58920908e+00,
#        -6.52977988e-01,  1.42490483e+00, -5.64399917e-01, -2.03792452e+00,
#        -1.11333557e-01,  8.03193015e-01, -1.09620426e+00,  1.87817277e-01,
#        -6.70435975e-01, -6.07890858e-01,  1.31335258e+00, -1.34070372e+00,
#         6.66678201e-01,  3.80012026e-04,  3.94530227e-01, -5.79979020e-01,
#         4.52280544e-02, -2.03313693e+00, -1.46386887e+00,  2.19686315e-01,
# ...

# %%
plt.hist(dataset1)
# Out:
# (array([ 7.,  6., 13., 16., 20., 13.,  6., 13.,  5.,  1.]),
#  array([-2.03792452, -1.57995281, -1.1219811 , -0.66400939, -0.20603767,
#          0.25193404,  0.70990575,  1.16787746,  1.62584917,  2.08382088,
#          2.54179259]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)
plt.hist(dataset2, color = 'indianred')
# Out:
# (array([ 3.,  5.,  8., 15., 16., 14., 10.,  4.,  3.,  2.]),
#  array([-2.29327902, -1.82766504, -1.36205106, -0.89643708, -0.4308231 ,
#          0.03479088,  0.50040486,  0.96601884,  1.43163282,  1.8972468 ,
#          2.36286078]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, color='indianred', alpha = .5, bins=20)
plt.hist(dataset2, alpha = .5, bins=10)
# Out:
# (array([ 3.,  5.,  8., 15., 16., 14., 10.,  4.,  3.,  2.]),
#  array([-2.29327902, -1.82766504, -1.36205106, -0.89643708, -0.4308231 ,
#          0.03479088,  0.50040486,  0.96601884,  1.43163282,  1.8972468 ,
#          2.36286078]),
#  <a list of 10 Patch objects>)

# %%
fig = plt.figure()

# %%
fig = plt.figure(figsize = (2,4), dpi =100)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
plt.plot(dataset1)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
plt.plot(data)
ax2 = fig.add_subplot(2,2,2)
plt.plot(s)
ax3 = fig.add_subplot(2,2,3)
plt.plot(dataset2)
ax4 = fig.add_subplot(2,2,4)
plt.plot(dataset1)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
plt.plot(data, 'k--')
ax2 = fig.add_subplot(2,2,2)
plt.plot(s, 'k--')
ax3 = fig.add_subplot(2,2,3)
plt.plot(dataset2)
ax4 = fig.add_subplot(2,2,4)
plt.plot(dataset1)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
plt.plot(dataset2)
ax4 = fig.add_subplot(2,2,4)
plt.plot(dataset1, 'k--')

ax1.hist(randn(100), bins = 20, color = 'k', alpha = .4)
ax2.scatter(np.arange(30), randn(30))

# %%
plt.plot(randn(30), 'ko--')

# %%
plt.plot(4 * randn(30), color = 'k', linestyle = 'dotted', marker = 'o')

# %%
plt.plot(4 * randn(30), color = 'k', linestyle = 'solid', marker = 'o')

# %%
plt.plot(4 * randn(30), color = 'k', linestyle = 'dashed', marker = 'o')

# %%
plt.plot(data, drawstyle = 'steps-post')

# %%
plt.plot(data, 'k--', label='Dashed line')
plt.plot(data, 'k--', drawstyle='steps-post', label='steps-post')
plt.legend(loc='best')

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.plot(randn(1000).cumsum())
ax.plot
# Out:
# <bound method Axes.plot of <matplotlib.axes._subplots.AxesSubplot object at 0x000001F8BDAAC488>>

# %%
ax.set_xticks([0,250,500,750,1000])
ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small')
ax.set_title('My first Matplotlip plot with xticks')
ax.set_xlabel('Stages')
ax.set_ylabel('Values')
fig

# %%
fig.savefig('fig1.png')
